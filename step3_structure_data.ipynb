# %% [markdown]
# # Step 3 - Structure data
#
# -- Alex Warwick Vesztrocy, Irene Julca, January 2024
#
# This notebook contains the code to download the structure data and compute the foldseek alignment.

# %% [markdown]
# ## 1 -- Download the structure data

# %%
from lib.PantherParser import PantherTrees
import glob
from tqdm.auto import tqdm
import pandas as pd 
import sys
import warnings

warnings.filterwarnings("ignore")

from parallel_pandas import ParallelPandas

# %%
pt = PantherTrees(
     "./data/panther-18.0/trees/",
     taxonomy_fn="./data/panther-18.0/species_tree.nhx",
)

# %%
def load_panther_mapping(pt):
    def load():
        for fam in pt.iter_fams():
            for g in fam.genes.values():
                r = {'fam_id': fam.id} | g
                for (k, v) in r.items():
                    if k.lower().startswith('ensembl'):
                        r[k] = v.split('.')[0]
                yield r
    return pd.DataFrame(load())

panther_genes = load_panther_mapping(pt)

# %%
# !mkdir -p /results/structure/genes

for (sp, zdf) in panther_genes[['species', 'UniProtKB']].groupby('species'):
    zdf[['UniProtKB']].sort_values('UniProtKB').to_csv(f'results/structure/genes/{sp}.tsv.gz', sep='\t', index=False, header=False)

# %%
for file in glob.glob('results/structure/genes/*'):
    sp = file.split('/')[-1].split('.')[0]
    cmd = f"./structure/get.py {file} {sp} results/structure/db"
    # !cmd

# %% [markdown]
# ## 2 -- Align with foldseek

# %%
# !mkdir -p results/structure/res_foldseek

! for SPECIES in `zcat results/outgroup_tests_structure.tsv.gz | cut -d $'\t' -f 20 | sort | uniq`; do\
if [ "$SPECIES" != "species" ]; \
then echo $SPECIES;\
PART=1;\
echo structure/align_foldseek.py results/outgroup_tests_structure.tsv.gz ${SPECIES} results/structure/db results/structure/res_foldseek/${SPECIES}_${PART}.h5 ${PART};\
PART=2;\
echo structure/align_foldseek.py results/outgroup_tests_structure.tsv.gz ${SPECIES} results/structure/db results/structure/res_foldseek/${SPECIES}_${PART}.h5 ${PART};\
PART=3;\
echo structure/align_foldseek.py results/outgroup_tests_structure.tsv.gz ${SPECIES} results/structure/db results/structure/res_foldseek/${SPECIES}_${PART}.h5 ${PART};\
fi;\
done
# Out:
# AMBTC
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz AMBTC ../results/structure/db ../results/structure/res_foldseek/AMBTC_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz AMBTC ../results/structure/db ../results/structure/res_foldseek/AMBTC_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz AMBTC ../results/structure/db ../results/structure/res_foldseek/AMBTC_3.h5 3
# ANOCA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ANOCA ../results/structure/db ../results/structure/res_foldseek/ANOCA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ANOCA ../results/structure/db ../results/structure/res_foldseek/ANOCA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ANOCA ../results/structure/db ../results/structure/res_foldseek/ANOCA_3.h5 3
# ANOGA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ANOGA ../results/structure/db ../results/structure/res_foldseek/ANOGA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ANOGA ../results/structure/db ../results/structure/res_foldseek/ANOGA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ANOGA ../results/structure/db ../results/structure/res_foldseek/ANOGA_3.h5 3
# AQUAE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz AQUAE ../results/structure/db ../results/structure/res_foldseek/AQUAE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz AQUAE ../results/structure/db ../results/structure/res_foldseek/AQUAE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz AQUAE ../results/structure/db ../results/structure/res_foldseek/AQUAE_3.h5 3
# ARATH
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ARATH ../results/structure/db ../results/structure/res_foldseek/ARATH_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ARATH ../results/structure/db ../results/structure/res_foldseek/ARATH_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ARATH ../results/structure/db ../results/structure/res_foldseek/ARATH_3.h5 3
# ASHGO
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ASHGO ../results/structure/db ../results/structure/res_foldseek/ASHGO_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ASHGO ../results/structure/db ../results/structure/res_foldseek/ASHGO_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ASHGO ../results/structure/db ../results/structure/res_foldseek/ASHGO_3.h5 3
# ASPFU
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ASPFU ../results/structure/db ../results/structure/res_foldseek/ASPFU_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ASPFU ../results/structure/db ../results/structure/res_foldseek/ASPFU_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ASPFU ../results/structure/db ../results/structure/res_foldseek/ASPFU_3.h5 3
# BACCR
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BACCR ../results/structure/db ../results/structure/res_foldseek/BACCR_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BACCR ../results/structure/db ../results/structure/res_foldseek/BACCR_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BACCR ../results/structure/db ../results/structure/res_foldseek/BACCR_3.h5 3
# BACSU
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BACSU ../results/structure/db ../results/structure/res_foldseek/BACSU_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BACSU ../results/structure/db ../results/structure/res_foldseek/BACSU_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BACSU ../results/structure/db ../results/structure/res_foldseek/BACSU_3.h5 3
# BACTN
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BACTN ../results/structure/db ../results/structure/res_foldseek/BACTN_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BACTN ../results/structure/db ../results/structure/res_foldseek/BACTN_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BACTN ../results/structure/db ../results/structure/res_foldseek/BACTN_3.h5 3
# BATDJ
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BATDJ ../results/structure/db ../results/structure/res_foldseek/BATDJ_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BATDJ ../results/structure/db ../results/structure/res_foldseek/BATDJ_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BATDJ ../results/structure/db ../results/structure/res_foldseek/BATDJ_3.h5 3
# BOVIN
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BOVIN ../results/structure/db ../results/structure/res_foldseek/BOVIN_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BOVIN ../results/structure/db ../results/structure/res_foldseek/BOVIN_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BOVIN ../results/structure/db ../results/structure/res_foldseek/BOVIN_3.h5 3
# BRADI
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRADI ../results/structure/db ../results/structure/res_foldseek/BRADI_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRADI ../results/structure/db ../results/structure/res_foldseek/BRADI_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRADI ../results/structure/db ../results/structure/res_foldseek/BRADI_3.h5 3
# BRADU
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRADU ../results/structure/db ../results/structure/res_foldseek/BRADU_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRADU ../results/structure/db ../results/structure/res_foldseek/BRADU_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRADU ../results/structure/db ../results/structure/res_foldseek/BRADU_3.h5 3
# BRAFL
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRAFL ../results/structure/db ../results/structure/res_foldseek/BRAFL_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRAFL ../results/structure/db ../results/structure/res_foldseek/BRAFL_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRAFL ../results/structure/db ../results/structure/res_foldseek/BRAFL_3.h5 3
# BRANA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRANA ../results/structure/db ../results/structure/res_foldseek/BRANA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRANA ../results/structure/db ../results/structure/res_foldseek/BRANA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRANA ../results/structure/db ../results/structure/res_foldseek/BRANA_3.h5 3
# BRARP
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRARP ../results/structure/db ../results/structure/res_foldseek/BRARP_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRARP ../results/structure/db ../results/structure/res_foldseek/BRARP_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz BRARP ../results/structure/db ../results/structure/res_foldseek/BRARP_3.h5 3
# CAEBR
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CAEBR ../results/structure/db ../results/structure/res_foldseek/CAEBR_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CAEBR ../results/structure/db ../results/structure/res_foldseek/CAEBR_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CAEBR ../results/structure/db ../results/structure/res_foldseek/CAEBR_3.h5 3
# CAEEL
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CAEEL ../results/structure/db ../results/structure/res_foldseek/CAEEL_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CAEEL ../results/structure/db ../results/structure/res_foldseek/CAEEL_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CAEEL ../results/structure/db ../results/structure/res_foldseek/CAEEL_3.h5 3
# CANAL
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CANAL ../results/structure/db ../results/structure/res_foldseek/CANAL_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CANAL ../results/structure/db ../results/structure/res_foldseek/CANAL_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CANAL ../results/structure/db ../results/structure/res_foldseek/CANAL_3.h5 3
# CANLF
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CANLF ../results/structure/db ../results/structure/res_foldseek/CANLF_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CANLF ../results/structure/db ../results/structure/res_foldseek/CANLF_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CANLF ../results/structure/db ../results/structure/res_foldseek/CANLF_3.h5 3
# CAPAN
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CAPAN ../results/structure/db ../results/structure/res_foldseek/CAPAN_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CAPAN ../results/structure/db ../results/structure/res_foldseek/CAPAN_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CAPAN ../results/structure/db ../results/structure/res_foldseek/CAPAN_3.h5 3
# CHICK
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CHICK ../results/structure/db ../results/structure/res_foldseek/CHICK_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CHICK ../results/structure/db ../results/structure/res_foldseek/CHICK_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CHICK ../results/structure/db ../results/structure/res_foldseek/CHICK_3.h5 3
# CHLAA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CHLAA ../results/structure/db ../results/structure/res_foldseek/CHLAA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CHLAA ../results/structure/db ../results/structure/res_foldseek/CHLAA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CHLAA ../results/structure/db ../results/structure/res_foldseek/CHLAA_3.h5 3
# CHLRE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CHLRE ../results/structure/db ../results/structure/res_foldseek/CHLRE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CHLRE ../results/structure/db ../results/structure/res_foldseek/CHLRE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CHLRE ../results/structure/db ../results/structure/res_foldseek/CHLRE_3.h5 3
# CHLTR
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CHLTR ../results/structure/db ../results/structure/res_foldseek/CHLTR_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CHLTR ../results/structure/db ../results/structure/res_foldseek/CHLTR_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CHLTR ../results/structure/db ../results/structure/res_foldseek/CHLTR_3.h5 3
# CIOIN
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CIOIN ../results/structure/db ../results/structure/res_foldseek/CIOIN_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CIOIN ../results/structure/db ../results/structure/res_foldseek/CIOIN_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CIOIN ../results/structure/db ../results/structure/res_foldseek/CIOIN_3.h5 3
# CITSI
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CITSI ../results/structure/db ../results/structure/res_foldseek/CITSI_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CITSI ../results/structure/db ../results/structure/res_foldseek/CITSI_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CITSI ../results/structure/db ../results/structure/res_foldseek/CITSI_3.h5 3
# CLOBH
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CLOBH ../results/structure/db ../results/structure/res_foldseek/CLOBH_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CLOBH ../results/structure/db ../results/structure/res_foldseek/CLOBH_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CLOBH ../results/structure/db ../results/structure/res_foldseek/CLOBH_3.h5 3
# COXBU
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz COXBU ../results/structure/db ../results/structure/res_foldseek/COXBU_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz COXBU ../results/structure/db ../results/structure/res_foldseek/COXBU_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz COXBU ../results/structure/db ../results/structure/res_foldseek/COXBU_3.h5 3
# CRYNJ
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CRYNJ ../results/structure/db ../results/structure/res_foldseek/CRYNJ_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CRYNJ ../results/structure/db ../results/structure/res_foldseek/CRYNJ_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CRYNJ ../results/structure/db ../results/structure/res_foldseek/CRYNJ_3.h5 3
# CUCSA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CUCSA ../results/structure/db ../results/structure/res_foldseek/CUCSA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CUCSA ../results/structure/db ../results/structure/res_foldseek/CUCSA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz CUCSA ../results/structure/db ../results/structure/res_foldseek/CUCSA_3.h5 3
# DANRE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DANRE ../results/structure/db ../results/structure/res_foldseek/DANRE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DANRE ../results/structure/db ../results/structure/res_foldseek/DANRE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DANRE ../results/structure/db ../results/structure/res_foldseek/DANRE_3.h5 3
# DAPPU
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DAPPU ../results/structure/db ../results/structure/res_foldseek/DAPPU_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DAPPU ../results/structure/db ../results/structure/res_foldseek/DAPPU_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DAPPU ../results/structure/db ../results/structure/res_foldseek/DAPPU_3.h5 3
# DEIRA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DEIRA ../results/structure/db ../results/structure/res_foldseek/DEIRA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DEIRA ../results/structure/db ../results/structure/res_foldseek/DEIRA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DEIRA ../results/structure/db ../results/structure/res_foldseek/DEIRA_3.h5 3
# DICDI
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DICDI ../results/structure/db ../results/structure/res_foldseek/DICDI_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DICDI ../results/structure/db ../results/structure/res_foldseek/DICDI_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DICDI ../results/structure/db ../results/structure/res_foldseek/DICDI_3.h5 3
# DICPU
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DICPU ../results/structure/db ../results/structure/res_foldseek/DICPU_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DICPU ../results/structure/db ../results/structure/res_foldseek/DICPU_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DICPU ../results/structure/db ../results/structure/res_foldseek/DICPU_3.h5 3
# DICTD
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DICTD ../results/structure/db ../results/structure/res_foldseek/DICTD_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DICTD ../results/structure/db ../results/structure/res_foldseek/DICTD_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DICTD ../results/structure/db ../results/structure/res_foldseek/DICTD_3.h5 3
# DROME
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DROME ../results/structure/db ../results/structure/res_foldseek/DROME_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DROME ../results/structure/db ../results/structure/res_foldseek/DROME_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz DROME ../results/structure/db ../results/structure/res_foldseek/DROME_3.h5 3
# ECOLI
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ECOLI ../results/structure/db ../results/structure/res_foldseek/ECOLI_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ECOLI ../results/structure/db ../results/structure/res_foldseek/ECOLI_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ECOLI ../results/structure/db ../results/structure/res_foldseek/ECOLI_3.h5 3
# EMENI
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz EMENI ../results/structure/db ../results/structure/res_foldseek/EMENI_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz EMENI ../results/structure/db ../results/structure/res_foldseek/EMENI_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz EMENI ../results/structure/db ../results/structure/res_foldseek/EMENI_3.h5 3
# ENTH1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ENTH1 ../results/structure/db ../results/structure/res_foldseek/ENTH1_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ENTH1 ../results/structure/db ../results/structure/res_foldseek/ENTH1_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ENTH1 ../results/structure/db ../results/structure/res_foldseek/ENTH1_3.h5 3
# ERYGU
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ERYGU ../results/structure/db ../results/structure/res_foldseek/ERYGU_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ERYGU ../results/structure/db ../results/structure/res_foldseek/ERYGU_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ERYGU ../results/structure/db ../results/structure/res_foldseek/ERYGU_3.h5 3
# EUCGR
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz EUCGR ../results/structure/db ../results/structure/res_foldseek/EUCGR_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz EUCGR ../results/structure/db ../results/structure/res_foldseek/EUCGR_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz EUCGR ../results/structure/db ../results/structure/res_foldseek/EUCGR_3.h5 3
# FELCA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz FELCA ../results/structure/db ../results/structure/res_foldseek/FELCA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz FELCA ../results/structure/db ../results/structure/res_foldseek/FELCA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz FELCA ../results/structure/db ../results/structure/res_foldseek/FELCA_3.h5 3
# FUSNN
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz FUSNN ../results/structure/db ../results/structure/res_foldseek/FUSNN_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz FUSNN ../results/structure/db ../results/structure/res_foldseek/FUSNN_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz FUSNN ../results/structure/db ../results/structure/res_foldseek/FUSNN_3.h5 3
# GEOSL
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GEOSL ../results/structure/db ../results/structure/res_foldseek/GEOSL_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GEOSL ../results/structure/db ../results/structure/res_foldseek/GEOSL_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GEOSL ../results/structure/db ../results/structure/res_foldseek/GEOSL_3.h5 3
# GIAIC
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GIAIC ../results/structure/db ../results/structure/res_foldseek/GIAIC_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GIAIC ../results/structure/db ../results/structure/res_foldseek/GIAIC_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GIAIC ../results/structure/db ../results/structure/res_foldseek/GIAIC_3.h5 3
# GLOVI
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GLOVI ../results/structure/db ../results/structure/res_foldseek/GLOVI_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GLOVI ../results/structure/db ../results/structure/res_foldseek/GLOVI_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GLOVI ../results/structure/db ../results/structure/res_foldseek/GLOVI_3.h5 3
# GORGO
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GORGO ../results/structure/db ../results/structure/res_foldseek/GORGO_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GORGO ../results/structure/db ../results/structure/res_foldseek/GORGO_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GORGO ../results/structure/db ../results/structure/res_foldseek/GORGO_3.h5 3
# GOSHI
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GOSHI ../results/structure/db ../results/structure/res_foldseek/GOSHI_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GOSHI ../results/structure/db ../results/structure/res_foldseek/GOSHI_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz GOSHI ../results/structure/db ../results/structure/res_foldseek/GOSHI_3.h5 3
# HAEIN
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HAEIN ../results/structure/db ../results/structure/res_foldseek/HAEIN_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HAEIN ../results/structure/db ../results/structure/res_foldseek/HAEIN_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HAEIN ../results/structure/db ../results/structure/res_foldseek/HAEIN_3.h5 3
# HALSA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HALSA ../results/structure/db ../results/structure/res_foldseek/HALSA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HALSA ../results/structure/db ../results/structure/res_foldseek/HALSA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HALSA ../results/structure/db ../results/structure/res_foldseek/HALSA_3.h5 3
# HELAN
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HELAN ../results/structure/db ../results/structure/res_foldseek/HELAN_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HELAN ../results/structure/db ../results/structure/res_foldseek/HELAN_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HELAN ../results/structure/db ../results/structure/res_foldseek/HELAN_3.h5 3
# HELPY
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HELPY ../results/structure/db ../results/structure/res_foldseek/HELPY_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HELPY ../results/structure/db ../results/structure/res_foldseek/HELPY_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HELPY ../results/structure/db ../results/structure/res_foldseek/HELPY_3.h5 3
# HELRO
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HELRO ../results/structure/db ../results/structure/res_foldseek/HELRO_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HELRO ../results/structure/db ../results/structure/res_foldseek/HELRO_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HELRO ../results/structure/db ../results/structure/res_foldseek/HELRO_3.h5 3
# HORSE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HORSE ../results/structure/db ../results/structure/res_foldseek/HORSE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HORSE ../results/structure/db ../results/structure/res_foldseek/HORSE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HORSE ../results/structure/db ../results/structure/res_foldseek/HORSE_3.h5 3
# HORVV
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HORVV ../results/structure/db ../results/structure/res_foldseek/HORVV_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HORVV ../results/structure/db ../results/structure/res_foldseek/HORVV_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HORVV ../results/structure/db ../results/structure/res_foldseek/HORVV_3.h5 3
# HUMAN
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HUMAN ../results/structure/db ../results/structure/res_foldseek/HUMAN_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HUMAN ../results/structure/db ../results/structure/res_foldseek/HUMAN_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz HUMAN ../results/structure/db ../results/structure/res_foldseek/HUMAN_3.h5 3
# IXOSC
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz IXOSC ../results/structure/db ../results/structure/res_foldseek/IXOSC_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz IXOSC ../results/structure/db ../results/structure/res_foldseek/IXOSC_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz IXOSC ../results/structure/db ../results/structure/res_foldseek/IXOSC_3.h5 3
# JUGRE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz JUGRE ../results/structure/db ../results/structure/res_foldseek/JUGRE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz JUGRE ../results/structure/db ../results/structure/res_foldseek/JUGRE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz JUGRE ../results/structure/db ../results/structure/res_foldseek/JUGRE_3.h5 3
# KLENI
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz KLENI ../results/structure/db ../results/structure/res_foldseek/KLENI_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz KLENI ../results/structure/db ../results/structure/res_foldseek/KLENI_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz KLENI ../results/structure/db ../results/structure/res_foldseek/KLENI_3.h5 3
# KORCO
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz KORCO ../results/structure/db ../results/structure/res_foldseek/KORCO_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz KORCO ../results/structure/db ../results/structure/res_foldseek/KORCO_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz KORCO ../results/structure/db ../results/structure/res_foldseek/KORCO_3.h5 3
# LACSA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LACSA ../results/structure/db ../results/structure/res_foldseek/LACSA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LACSA ../results/structure/db ../results/structure/res_foldseek/LACSA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LACSA ../results/structure/db ../results/structure/res_foldseek/LACSA_3.h5 3
# LEIMA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LEIMA ../results/structure/db ../results/structure/res_foldseek/LEIMA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LEIMA ../results/structure/db ../results/structure/res_foldseek/LEIMA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LEIMA ../results/structure/db ../results/structure/res_foldseek/LEIMA_3.h5 3
# LEPIN
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LEPIN ../results/structure/db ../results/structure/res_foldseek/LEPIN_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LEPIN ../results/structure/db ../results/structure/res_foldseek/LEPIN_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LEPIN ../results/structure/db ../results/structure/res_foldseek/LEPIN_3.h5 3
# LEPOC
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LEPOC ../results/structure/db ../results/structure/res_foldseek/LEPOC_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LEPOC ../results/structure/db ../results/structure/res_foldseek/LEPOC_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LEPOC ../results/structure/db ../results/structure/res_foldseek/LEPOC_3.h5 3
# LISMO
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LISMO ../results/structure/db ../results/structure/res_foldseek/LISMO_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LISMO ../results/structure/db ../results/structure/res_foldseek/LISMO_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz LISMO ../results/structure/db ../results/structure/res_foldseek/LISMO_3.h5 3
# MACMU
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MACMU ../results/structure/db ../results/structure/res_foldseek/MACMU_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MACMU ../results/structure/db ../results/structure/res_foldseek/MACMU_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MACMU ../results/structure/db ../results/structure/res_foldseek/MACMU_3.h5 3
# MAIZE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MAIZE ../results/structure/db ../results/structure/res_foldseek/MAIZE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MAIZE ../results/structure/db ../results/structure/res_foldseek/MAIZE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MAIZE ../results/structure/db ../results/structure/res_foldseek/MAIZE_3.h5 3
# MANES
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MANES ../results/structure/db ../results/structure/res_foldseek/MANES_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MANES ../results/structure/db ../results/structure/res_foldseek/MANES_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MANES ../results/structure/db ../results/structure/res_foldseek/MANES_3.h5 3
# MARPO
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MARPO ../results/structure/db ../results/structure/res_foldseek/MARPO_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MARPO ../results/structure/db ../results/structure/res_foldseek/MARPO_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MARPO ../results/structure/db ../results/structure/res_foldseek/MARPO_3.h5 3
# MEDTR
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MEDTR ../results/structure/db ../results/structure/res_foldseek/MEDTR_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MEDTR ../results/structure/db ../results/structure/res_foldseek/MEDTR_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MEDTR ../results/structure/db ../results/structure/res_foldseek/MEDTR_3.h5 3
# METAC
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz METAC ../results/structure/db ../results/structure/res_foldseek/METAC_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz METAC ../results/structure/db ../results/structure/res_foldseek/METAC_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz METAC ../results/structure/db ../results/structure/res_foldseek/METAC_3.h5 3
# METJA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz METJA ../results/structure/db ../results/structure/res_foldseek/METJA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz METJA ../results/structure/db ../results/structure/res_foldseek/METJA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz METJA ../results/structure/db ../results/structure/res_foldseek/METJA_3.h5 3
# MONBE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MONBE ../results/structure/db ../results/structure/res_foldseek/MONBE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MONBE ../results/structure/db ../results/structure/res_foldseek/MONBE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MONBE ../results/structure/db ../results/structure/res_foldseek/MONBE_3.h5 3
# MONDO
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MONDO ../results/structure/db ../results/structure/res_foldseek/MONDO_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MONDO ../results/structure/db ../results/structure/res_foldseek/MONDO_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MONDO ../results/structure/db ../results/structure/res_foldseek/MONDO_3.h5 3
# MOUSE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MOUSE ../results/structure/db ../results/structure/res_foldseek/MOUSE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MOUSE ../results/structure/db ../results/structure/res_foldseek/MOUSE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MOUSE ../results/structure/db ../results/structure/res_foldseek/MOUSE_3.h5 3
# MUSAM
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MUSAM ../results/structure/db ../results/structure/res_foldseek/MUSAM_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MUSAM ../results/structure/db ../results/structure/res_foldseek/MUSAM_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MUSAM ../results/structure/db ../results/structure/res_foldseek/MUSAM_3.h5 3
# MYCGE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MYCGE ../results/structure/db ../results/structure/res_foldseek/MYCGE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MYCGE ../results/structure/db ../results/structure/res_foldseek/MYCGE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MYCGE ../results/structure/db ../results/structure/res_foldseek/MYCGE_3.h5 3
# MYCTU
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MYCTU ../results/structure/db ../results/structure/res_foldseek/MYCTU_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MYCTU ../results/structure/db ../results/structure/res_foldseek/MYCTU_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz MYCTU ../results/structure/db ../results/structure/res_foldseek/MYCTU_3.h5 3
# NEIMB
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NEIMB ../results/structure/db ../results/structure/res_foldseek/NEIMB_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NEIMB ../results/structure/db ../results/structure/res_foldseek/NEIMB_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NEIMB ../results/structure/db ../results/structure/res_foldseek/NEIMB_3.h5 3
# NELNU
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NELNU ../results/structure/db ../results/structure/res_foldseek/NELNU_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NELNU ../results/structure/db ../results/structure/res_foldseek/NELNU_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NELNU ../results/structure/db ../results/structure/res_foldseek/NELNU_3.h5 3
# NEMVE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NEMVE ../results/structure/db ../results/structure/res_foldseek/NEMVE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NEMVE ../results/structure/db ../results/structure/res_foldseek/NEMVE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NEMVE ../results/structure/db ../results/structure/res_foldseek/NEMVE_3.h5 3
# NEUCR
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NEUCR ../results/structure/db ../results/structure/res_foldseek/NEUCR_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NEUCR ../results/structure/db ../results/structure/res_foldseek/NEUCR_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NEUCR ../results/structure/db ../results/structure/res_foldseek/NEUCR_3.h5 3
# NITMS
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NITMS ../results/structure/db ../results/structure/res_foldseek/NITMS_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NITMS ../results/structure/db ../results/structure/res_foldseek/NITMS_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz NITMS ../results/structure/db ../results/structure/res_foldseek/NITMS_3.h5 3
# ORNAN
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ORNAN ../results/structure/db ../results/structure/res_foldseek/ORNAN_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ORNAN ../results/structure/db ../results/structure/res_foldseek/ORNAN_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ORNAN ../results/structure/db ../results/structure/res_foldseek/ORNAN_3.h5 3
# ORYLA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ORYLA ../results/structure/db ../results/structure/res_foldseek/ORYLA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ORYLA ../results/structure/db ../results/structure/res_foldseek/ORYLA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ORYLA ../results/structure/db ../results/structure/res_foldseek/ORYLA_3.h5 3
# ORYSJ
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ORYSJ ../results/structure/db ../results/structure/res_foldseek/ORYSJ_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ORYSJ ../results/structure/db ../results/structure/res_foldseek/ORYSJ_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ORYSJ ../results/structure/db ../results/structure/res_foldseek/ORYSJ_3.h5 3
# PANTR
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PANTR ../results/structure/db ../results/structure/res_foldseek/PANTR_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PANTR ../results/structure/db ../results/structure/res_foldseek/PANTR_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PANTR ../results/structure/db ../results/structure/res_foldseek/PANTR_3.h5 3
# PARTE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PARTE ../results/structure/db ../results/structure/res_foldseek/PARTE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PARTE ../results/structure/db ../results/structure/res_foldseek/PARTE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PARTE ../results/structure/db ../results/structure/res_foldseek/PARTE_3.h5 3
# PHANO
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PHANO ../results/structure/db ../results/structure/res_foldseek/PHANO_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PHANO ../results/structure/db ../results/structure/res_foldseek/PHANO_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PHANO ../results/structure/db ../results/structure/res_foldseek/PHANO_3.h5 3
# PHYPA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PHYPA ../results/structure/db ../results/structure/res_foldseek/PHYPA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PHYPA ../results/structure/db ../results/structure/res_foldseek/PHYPA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PHYPA ../results/structure/db ../results/structure/res_foldseek/PHYPA_3.h5 3
# PHYRM
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PHYRM ../results/structure/db ../results/structure/res_foldseek/PHYRM_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PHYRM ../results/structure/db ../results/structure/res_foldseek/PHYRM_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PHYRM ../results/structure/db ../results/structure/res_foldseek/PHYRM_3.h5 3
# PIG
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PIG ../results/structure/db ../results/structure/res_foldseek/PIG_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PIG ../results/structure/db ../results/structure/res_foldseek/PIG_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PIG ../results/structure/db ../results/structure/res_foldseek/PIG_3.h5 3
# PLAF7
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PLAF7 ../results/structure/db ../results/structure/res_foldseek/PLAF7_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PLAF7 ../results/structure/db ../results/structure/res_foldseek/PLAF7_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PLAF7 ../results/structure/db ../results/structure/res_foldseek/PLAF7_3.h5 3
# POPTR
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz POPTR ../results/structure/db ../results/structure/res_foldseek/POPTR_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz POPTR ../results/structure/db ../results/structure/res_foldseek/POPTR_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz POPTR ../results/structure/db ../results/structure/res_foldseek/POPTR_3.h5 3
# PRIPA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PRIPA ../results/structure/db ../results/structure/res_foldseek/PRIPA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PRIPA ../results/structure/db ../results/structure/res_foldseek/PRIPA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PRIPA ../results/structure/db ../results/structure/res_foldseek/PRIPA_3.h5 3
# PRUPE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PRUPE ../results/structure/db ../results/structure/res_foldseek/PRUPE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PRUPE ../results/structure/db ../results/structure/res_foldseek/PRUPE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PRUPE ../results/structure/db ../results/structure/res_foldseek/PRUPE_3.h5 3
# PSEAE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PSEAE ../results/structure/db ../results/structure/res_foldseek/PSEAE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PSEAE ../results/structure/db ../results/structure/res_foldseek/PSEAE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PSEAE ../results/structure/db ../results/structure/res_foldseek/PSEAE_3.h5 3
# PUCGT
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PUCGT ../results/structure/db ../results/structure/res_foldseek/PUCGT_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PUCGT ../results/structure/db ../results/structure/res_foldseek/PUCGT_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PUCGT ../results/structure/db ../results/structure/res_foldseek/PUCGT_3.h5 3
# PYRAE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PYRAE ../results/structure/db ../results/structure/res_foldseek/PYRAE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PYRAE ../results/structure/db ../results/structure/res_foldseek/PYRAE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz PYRAE ../results/structure/db ../results/structure/res_foldseek/PYRAE_3.h5 3
# RAT
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz RAT ../results/structure/db ../results/structure/res_foldseek/RAT_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz RAT ../results/structure/db ../results/structure/res_foldseek/RAT_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz RAT ../results/structure/db ../results/structure/res_foldseek/RAT_3.h5 3
# RHOBA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz RHOBA ../results/structure/db ../results/structure/res_foldseek/RHOBA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz RHOBA ../results/structure/db ../results/structure/res_foldseek/RHOBA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz RHOBA ../results/structure/db ../results/structure/res_foldseek/RHOBA_3.h5 3
# RICCO
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz RICCO ../results/structure/db ../results/structure/res_foldseek/RICCO_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz RICCO ../results/structure/db ../results/structure/res_foldseek/RICCO_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz RICCO ../results/structure/db ../results/structure/res_foldseek/RICCO_3.h5 3
# SACS2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SACS2 ../results/structure/db ../results/structure/res_foldseek/SACS2_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SACS2 ../results/structure/db ../results/structure/res_foldseek/SACS2_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SACS2 ../results/structure/db ../results/structure/res_foldseek/SACS2_3.h5 3
# SALTY
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SALTY ../results/structure/db ../results/structure/res_foldseek/SALTY_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SALTY ../results/structure/db ../results/structure/res_foldseek/SALTY_2.h5 2
# ...
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SCHJY ../results/structure/db ../results/structure/res_foldseek/SCHJY_3.h5 3
# SCHPO
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SCHPO ../results/structure/db ../results/structure/res_foldseek/SCHPO_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SCHPO ../results/structure/db ../results/structure/res_foldseek/SCHPO_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SCHPO ../results/structure/db ../results/structure/res_foldseek/SCHPO_3.h5 3
# SCLS1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SCLS1 ../results/structure/db ../results/structure/res_foldseek/SCLS1_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SCLS1 ../results/structure/db ../results/structure/res_foldseek/SCLS1_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SCLS1 ../results/structure/db ../results/structure/res_foldseek/SCLS1_3.h5 3
# SELML
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SELML ../results/structure/db ../results/structure/res_foldseek/SELML_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SELML ../results/structure/db ../results/structure/res_foldseek/SELML_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SELML ../results/structure/db ../results/structure/res_foldseek/SELML_3.h5 3
# SETIT
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SETIT ../results/structure/db ../results/structure/res_foldseek/SETIT_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SETIT ../results/structure/db ../results/structure/res_foldseek/SETIT_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SETIT ../results/structure/db ../results/structure/res_foldseek/SETIT_3.h5 3
# SHEON
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SHEON ../results/structure/db ../results/structure/res_foldseek/SHEON_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SHEON ../results/structure/db ../results/structure/res_foldseek/SHEON_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SHEON ../results/structure/db ../results/structure/res_foldseek/SHEON_3.h5 3
# SOLLC
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SOLLC ../results/structure/db ../results/structure/res_foldseek/SOLLC_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SOLLC ../results/structure/db ../results/structure/res_foldseek/SOLLC_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SOLLC ../results/structure/db ../results/structure/res_foldseek/SOLLC_3.h5 3
# SOLTU
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SOLTU ../results/structure/db ../results/structure/res_foldseek/SOLTU_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SOLTU ../results/structure/db ../results/structure/res_foldseek/SOLTU_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SOLTU ../results/structure/db ../results/structure/res_foldseek/SOLTU_3.h5 3
# SORBI
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SORBI ../results/structure/db ../results/structure/res_foldseek/SORBI_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SORBI ../results/structure/db ../results/structure/res_foldseek/SORBI_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SORBI ../results/structure/db ../results/structure/res_foldseek/SORBI_3.h5 3
# SOYBN
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SOYBN ../results/structure/db ../results/structure/res_foldseek/SOYBN_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SOYBN ../results/structure/db ../results/structure/res_foldseek/SOYBN_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SOYBN ../results/structure/db ../results/structure/res_foldseek/SOYBN_3.h5 3
# SPIOL
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SPIOL ../results/structure/db ../results/structure/res_foldseek/SPIOL_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SPIOL ../results/structure/db ../results/structure/res_foldseek/SPIOL_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SPIOL ../results/structure/db ../results/structure/res_foldseek/SPIOL_3.h5 3
# STAA8
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz STAA8 ../results/structure/db ../results/structure/res_foldseek/STAA8_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz STAA8 ../results/structure/db ../results/structure/res_foldseek/STAA8_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz STAA8 ../results/structure/db ../results/structure/res_foldseek/STAA8_3.h5 3
# STRCO
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz STRCO ../results/structure/db ../results/structure/res_foldseek/STRCO_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz STRCO ../results/structure/db ../results/structure/res_foldseek/STRCO_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz STRCO ../results/structure/db ../results/structure/res_foldseek/STRCO_3.h5 3
# STRPU
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz STRPU ../results/structure/db ../results/structure/res_foldseek/STRPU_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz STRPU ../results/structure/db ../results/structure/res_foldseek/STRPU_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz STRPU ../results/structure/db ../results/structure/res_foldseek/STRPU_3.h5 3
# STRR6
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz STRR6 ../results/structure/db ../results/structure/res_foldseek/STRR6_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz STRR6 ../results/structure/db ../results/structure/res_foldseek/STRR6_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz STRR6 ../results/structure/db ../results/structure/res_foldseek/STRR6_3.h5 3
# SYNY3
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SYNY3 ../results/structure/db ../results/structure/res_foldseek/SYNY3_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SYNY3 ../results/structure/db ../results/structure/res_foldseek/SYNY3_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz SYNY3 ../results/structure/db ../results/structure/res_foldseek/SYNY3_3.h5 3
# THAPS
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THAPS ../results/structure/db ../results/structure/res_foldseek/THAPS_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THAPS ../results/structure/db ../results/structure/res_foldseek/THAPS_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THAPS ../results/structure/db ../results/structure/res_foldseek/THAPS_3.h5 3
# THECC
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THECC ../results/structure/db ../results/structure/res_foldseek/THECC_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THECC ../results/structure/db ../results/structure/res_foldseek/THECC_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THECC ../results/structure/db ../results/structure/res_foldseek/THECC_3.h5 3
# THEKO
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THEKO ../results/structure/db ../results/structure/res_foldseek/THEKO_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THEKO ../results/structure/db ../results/structure/res_foldseek/THEKO_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THEKO ../results/structure/db ../results/structure/res_foldseek/THEKO_3.h5 3
# THEMA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THEMA ../results/structure/db ../results/structure/res_foldseek/THEMA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THEMA ../results/structure/db ../results/structure/res_foldseek/THEMA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THEMA ../results/structure/db ../results/structure/res_foldseek/THEMA_3.h5 3
# THEYD
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THEYD ../results/structure/db ../results/structure/res_foldseek/THEYD_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THEYD ../results/structure/db ../results/structure/res_foldseek/THEYD_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz THEYD ../results/structure/db ../results/structure/res_foldseek/THEYD_3.h5 3
# TOBAC
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TOBAC ../results/structure/db ../results/structure/res_foldseek/TOBAC_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TOBAC ../results/structure/db ../results/structure/res_foldseek/TOBAC_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TOBAC ../results/structure/db ../results/structure/res_foldseek/TOBAC_3.h5 3
# TRIAD
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TRIAD ../results/structure/db ../results/structure/res_foldseek/TRIAD_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TRIAD ../results/structure/db ../results/structure/res_foldseek/TRIAD_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TRIAD ../results/structure/db ../results/structure/res_foldseek/TRIAD_3.h5 3
# TRICA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TRICA ../results/structure/db ../results/structure/res_foldseek/TRICA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TRICA ../results/structure/db ../results/structure/res_foldseek/TRICA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TRICA ../results/structure/db ../results/structure/res_foldseek/TRICA_3.h5 3
# TRIVA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TRIVA ../results/structure/db ../results/structure/res_foldseek/TRIVA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TRIVA ../results/structure/db ../results/structure/res_foldseek/TRIVA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TRIVA ../results/structure/db ../results/structure/res_foldseek/TRIVA_3.h5 3
# TRYB2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TRYB2 ../results/structure/db ../results/structure/res_foldseek/TRYB2_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TRYB2 ../results/structure/db ../results/structure/res_foldseek/TRYB2_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz TRYB2 ../results/structure/db ../results/structure/res_foldseek/TRYB2_3.h5 3
# USTMA
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz USTMA ../results/structure/db ../results/structure/res_foldseek/USTMA_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz USTMA ../results/structure/db ../results/structure/res_foldseek/USTMA_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz USTMA ../results/structure/db ../results/structure/res_foldseek/USTMA_3.h5 3
# VIBCH
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz VIBCH ../results/structure/db ../results/structure/res_foldseek/VIBCH_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz VIBCH ../results/structure/db ../results/structure/res_foldseek/VIBCH_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz VIBCH ../results/structure/db ../results/structure/res_foldseek/VIBCH_3.h5 3
# VITVI
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz VITVI ../results/structure/db ../results/structure/res_foldseek/VITVI_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz VITVI ../results/structure/db ../results/structure/res_foldseek/VITVI_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz VITVI ../results/structure/db ../results/structure/res_foldseek/VITVI_3.h5 3
# WHEAT
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz WHEAT ../results/structure/db ../results/structure/res_foldseek/WHEAT_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz WHEAT ../results/structure/db ../results/structure/res_foldseek/WHEAT_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz WHEAT ../results/structure/db ../results/structure/res_foldseek/WHEAT_3.h5 3
# XANCP
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz XANCP ../results/structure/db ../results/structure/res_foldseek/XANCP_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz XANCP ../results/structure/db ../results/structure/res_foldseek/XANCP_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz XANCP ../results/structure/db ../results/structure/res_foldseek/XANCP_3.h5 3
# XENTR
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz XENTR ../results/structure/db ../results/structure/res_foldseek/XENTR_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz XENTR ../results/structure/db ../results/structure/res_foldseek/XENTR_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz XENTR ../results/structure/db ../results/structure/res_foldseek/XENTR_3.h5 3
# YARLI
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz YARLI ../results/structure/db ../results/structure/res_foldseek/YARLI_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz YARLI ../results/structure/db ../results/structure/res_foldseek/YARLI_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz YARLI ../results/structure/db ../results/structure/res_foldseek/YARLI_3.h5 3
# YEAST
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz YEAST ../results/structure/db ../results/structure/res_foldseek/YEAST_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz YEAST ../results/structure/db ../results/structure/res_foldseek/YEAST_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz YEAST ../results/structure/db ../results/structure/res_foldseek/YEAST_3.h5 3
# YERPE
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz YERPE ../results/structure/db ../results/structure/res_foldseek/YERPE_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz YERPE ../results/structure/db ../results/structure/res_foldseek/YERPE_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz YERPE ../results/structure/db ../results/structure/res_foldseek/YERPE_3.h5 3
# ZOSMR
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ZOSMR ../results/structure/db ../results/structure/res_foldseek/ZOSMR_1.h5 1
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ZOSMR ../results/structure/db ../results/structure/res_foldseek/ZOSMR_2.h5 2
# structure/align_foldseek.py ../results/outgroup_tests_structure.tsv.gz ZOSMR ../results/structure/db ../results/structure/res_foldseek/ZOSMR_3.h5 3

# %% [markdown]
# ## 3 -- Combine for results

# %%
ParallelPandas.initialize()

pair_fn = 'results/outgroup_tests_structure.tsv.gz'
db_path = 'results/structure/res_foldseek/'
out_fn = 'results/structure/structure_results_FOLDSEEK.h5'

pair_df = pd.read_csv(pair_fn, sep='\t')
for (sp, zdf) in tqdm(pair_df.groupby('species')):
    print(sp)
    rmsd = pd.read_hdf(f'{db_path}/{sp}_1.h5', sp).set_index(['gene1', 'gene2'])['lddt'].to_dict()
    zdf['struct_ldo_mdo_lddt'] = zdf.p_apply(lambda x: rmsd.get((x['ldo_gene'], x['mdo_gene']), None), axis=1)

    rmsd = pd.read_hdf(f'{db_path}/{sp}_2.h5', sp).set_index(['gene1', 'gene2'])['lddt'].to_dict()
    zdf['struct_ldo_out_lddt'] = zdf.p_apply(lambda x: rmsd.get((x['ldo_gene'], x['out_gene']), None) if pd.notna(x['out_gene']) e
lse None, axis=1)

    rmsd = pd.read_hdf(f'{db_path}/{sp}_3.h5', sp).set_index(['gene1', 'gene2'])['lddt'].to_dict()
    zdf['struct_mdo_out_lddt'] = zdf.p_apply(lambda x: rmsd.get((x['mdo_gene'], x['out_gene']), None) if pd.notna(x['out_gene']) e
lse None, axis=1)

    zdf.to_hdf(out_fn, sp)
